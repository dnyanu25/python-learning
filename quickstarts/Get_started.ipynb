# %% [markdown]
# <a href="https://colab.research.google.com/github/dnyanu25/python-learning/blob/main/quickstarts/Get_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2025 Google LLC.

# %%
print("learn python")
# Out:
# learn python

# %%
class Agent:
  def __init__(self,task):
       self.task=task
  def Act(self,task):
       if task == "hello":
         return "hi user"
       else :
         return "not identified"
  agent=Agent("hello")
  agent.Act("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3533028978.py in <cell line: 0>()
# ----> 1 class Agent:
#       2   def __init__(self,task):
#       3        self.task=task
#       4   def Act(self,task):
#       5        if task == "hello":
#
# /tmp/ipython-input-3533028978.py in Agent()
#       7        else :
#       8          return "not identified"
# ----> 9   agent=Agent("hello")
#      10   agent.Act("hello")
#
# NameError: name 'Agent' is not defined
